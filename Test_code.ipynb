# %% [markdown]
# <a href="https://colab.research.google.com/github/potdarchinmay3007/AIML_COHORT_ASSIGNMENT/blob/main/Test_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pytorch code
import torch
import torch.nn as nn

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.layer2 = nn.Linear(in_features=20, out_features=10)
        #follow with the ReLu
        nn.ReLU()
    def forward(self, x):
      x = torch.flatten(1.0, -1.0) # (batch dimension is 0)
        # Pass tensor through the linear layer
      x = self.layer1(x)
      return x
      # create the complex mappings between the model’s inputs and outputs. They are applied after linear transformations to introduce nonlinearity, helping neural networks learn a wide variety of phenomena.

# %%
#do_sample = True
from transformers import pipeline

generator = pipeline(model="openai-community/gpt2")
generator("Once upon a time", do_sample=False)

# These parameters will return suggestions, and only the newly created text making it easier for prompting suggestions.
outputs = generator("My tart needs some", num_return_sequences=4, return_full_text=False)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'do_sample'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# ...

# %%
#do_sample = True
from transformers import pipeline

generator = pipeline(model="openai-community/gpt2")
generator("Once upon a time", do_sample=True)

# These parameters will return suggestions, and only the newly created text making it easier for prompting suggestions.
outputs = generator("My tart needs some", num_return_sequences=4, return_full_text=True)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
